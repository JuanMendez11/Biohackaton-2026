# %%
import pandas as pd
df = pd.read_csv("data/PubChem_compound_reactive_dye.csv")

# %%
df.head()
# Out:
#    Compound_CID                   Name  \
# 0         73264       Reactive Red 120
# 1     156595263      Reactive Yellow 2
# 2     156592287     Reactive Orange 16
# 3         25863        Reactive Blue 4
# 4     135442967  C.I. Reactive Black 5
#
#                                             Synonyms   Molecular_Formula  \
# 0  Reactive Red 120|61951-82-4|C.I. Reactive Red ...   C44H30Cl2N14O20S6
# 1  RefChem:878991|reactive yellow 2 textile dye|5...  C25H18Cl3N9NaO10S3
# 2        OR 16 dye|RefChem:878964|Reactive Orange 16     C20H19N3NaO11S3
# 3  Reactive Blue 4|Procion blue MX-R|13324-20-4|C...     C23H14Cl2N6O8S2
# 4  C.I. REACTIVE BLACK 5|DTXSID4027787|RefChem:10...    C26H21N5Na4O19S6
#
#                                                InChI  \
# 0  InChI=1S/C44H30Cl2N14O20S6/c45-39-51-41(55-43(...
# 1  InChI=1S/C25H18Cl3N9O10S3.Na/c1-11-21(22(38)37...
# 2  InChI=1S/C20H19N3O11S3.Na/c1-12(24)21-15-3-2-1...
# 3  InChI=1S/C23H14Cl2N6O8S2/c24-21-29-22(25)31-23...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 38 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Compound_CID                        14 non-null     int64
#  1   Name                                14 non-null     object
#  2   Synonyms                            14 non-null     object
#  3   Molecular_Formula                   14 non-null     object
#  4   InChI                               14 non-null     object
#  5   SMILES                              14 non-null     object
#  6   InChIKey                            14 non-null     object
#  7   IUPAC_Name                          12 non-null     object
#  8   MeSH_Headings                       4 non-null      object
#  9   Annotation_Content                  13 non-null     object
#  10  Linked_BioAssays                    4 non-null      object
# ...
